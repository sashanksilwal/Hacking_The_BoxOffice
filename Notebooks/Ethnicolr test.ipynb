# %%
pip install ethnicolr
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 36.8 MB 142 kB/s
# ...

# %%
import pandas as pd

from ethnicolr import census_ln, pred_census_ln

names = [
{"first": "Pedro", "last": "Velasquez"},
{"last": "Khalili", "first": "Khalili"},
{'last': 'larhlimi', 'first': 'imane'},
# {'last': 'shaimardanov', 'first': 'shaimardanov'},
# {'last': 'freeman', 'first': 'freeman'},
# {'last': 'golding', 'first': 'golding'}  
]

# %%
df = pd.DataFrame(names)

# %%
df
# Out:
#      first       last
# 0    Pedro  Velasquez
# 1  Khalili    Khalili
# 2    imane   larhlimi

# %%
census_ln(df, 'last')
# Out:
#      first       last pctwhite pctblack pctapi pctaian pct2prace pcthispanic
# 0    Pedro  Velasquez     5.34     0.57   1.74    0.59      0.51       91.26
# 1  Khalili    Khalili    78.97      (S)   2.72     (S)     16.79        1.36
# 2    imane   larhlimi      NaN      NaN    NaN     NaN       NaN         NaN

# %%
from ethnicolr import pred_nc_reg_name

# %%
names = [
{'last': 'Davis', 'first': 'Viola'},
{"first": "Sashank", "last": "Silwal"},
{"last": "Khalili", "first": "Maryam"},
{'last': 'Hoang', 'first': 'Ngoc'},
{'last': 'Shaimardanov', 'first': 'Alem'},
{'last': 'Washington', 'first': 'Denzel'},
{'last': 'Patel', 'first': 'Dev'},
{'last': 'Cruise', 'first': 'Tom'},

  
]

# %%
df = pd.DataFrame(names)

# %%
odf = pred_nc_reg_name(df, 'last', 'first')

# %%
odf[["first", "last", "race"]]
# Out:
#      first          last  race
# 0    Viola         Davis  NL+B
# 1  Sashank        Silwal  NL+A
# 2   Maryam       Khalili  NL+O
# 3     Ngoc         Hoang  NL+A
# 4     Alem  Shaimardanov  NL+O
# 5   Denzel    Washington  NL+B
# 6      Dev         Patel  NL+A
# 7      Tom        Cruise  NL+W
