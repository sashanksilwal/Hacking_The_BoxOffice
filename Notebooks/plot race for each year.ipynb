# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import seaborn as sns
import requests
import json
import numpy as np
from scipy.stats import chi2_contingency
import scipy.stats as stats

# %%
# loading the data
total_movies = pd.read_csv("movies_exp_00_19.csv")
movies = pd.read_csv("movies_cast_2.csv")
principals = pd.read_csv("principals.csv")
filtered_movies = pd.read_csv("filtered_movies.csv")
ethnicity = pd.read_csv("cleaned_race_name.csv")

# %%
total_movies.head()
# Out:
#       tconst titleType      primaryTitle     originalTitle  isAdult  \
# 0  tt0011801     movie  Tötet nicht mehr  Tötet nicht mehr        0
# 1  tt0011801     movie  Tötet nicht mehr  Tötet nicht mehr        0
# 2  tt0035423     movie    Kate & Leopold    Kate & Leopold        0
# 3  tt0035423     movie    Kate & Leopold    Kate & Leopold        0
# 4  tt0035423     movie    Kate & Leopold    Kate & Leopold        0
#
#    startYear  endYear  runtimeMinutes                  genres genres_sep
# 0     2019.0      NaN             NaN            Action,Crime     Action
# 1     2019.0      NaN             NaN            Action,Crime      Crime
# 2     2001.0      NaN           118.0  Comedy,Fantasy,Romance     Comedy
# 3     2001.0      NaN           118.0  Comedy,Fantasy,Romance    Fantasy
# 4     2001.0      NaN           118.0  Comedy,Fantasy,Romance    Romance

# %%
movies_exp = movies.assign(genres_sep = movies['genres'].str.split(',')).explode("genres_sep")
movies_exp.head()
# Out:
#    index     tconst titleType         primaryTitle        originalTitle  \
# 0   7363  tt1179904     movie  Paranormal Activity  Paranormal Activity
# 0   7363  tt1179904     movie  Paranormal Activity  Paranormal Activity
# 1   4907  tt2309260     movie          The Gallows          The Gallows
# 1   4907  tt2309260     movie          The Gallows          The Gallows
# 1   4907  tt2309260     movie          The Gallows          The Gallows
#
#    isAdult  startYear  endYear  runtimeMinutes                   genres  ...  \
# 0        0       2007      NaN              86           Horror,Mystery  ...
# 0        0       2007      NaN              86           Horror,Mystery  ...
# 1        0       2015      NaN              81  Horror,Mystery,Thriller  ...
# 1        0       2015      NaN              81  Horror,Mystery,Thriller  ...
# 1        0       2015      NaN              81  Horror,Mystery,Thriller  ...
#
#    og_language  budget    revenue     ratio         ROI  averageRating  \
# 0           en  230000  194183034  0.001184  844.274061            6.3
# 0           en  230000  194183034  0.001184  844.274061            6.3
# 1           en  100000   42664410  0.002344  426.644100            4.2
# 1           en  100000   42664410  0.002344  426.644100            4.2
# 1           en  100000   42664410  0.002344  426.644100            4.2
#
#    numVotes               Unnamed: 18  \
# 0    238846  Info says budget is $15k
# 0    238846  Info says budget is $15k
# 1     20611                       NaN
# 1     20611                       NaN
# 1     20611                       NaN
#
#                                               nconst genres_sep
# 0  ['nm2209370', 'nm2913790', 'nm2104166', 'nm291...     Horror
# 0  ['nm2209370', 'nm2913790', 'nm2104166', 'nm291...    Mystery
# 1  ['nm3790547', 'nm6018502', 'nm4090362', 'nm225...     Horror
# 1  ['nm3790547', 'nm6018502', 'nm4090362', 'nm225...    Mystery
# 1  ['nm3790547', 'nm6018502', 'nm4090362', 'nm225...   Thriller
#
# [5 rows x 21 columns]

# %%
principals.head()
# Out:
#       tconst  ordering     nconst category job         characters
# 0  tt0035423         1  nm0000212  actress  \N     ["Kate McKay"]
# 1  tt0035423         2  nm0413168    actor  \N        ["Leopold"]
# 2  tt0035423         3  nm0000630    actor  \N  ["Stuart Besser"]
# 3  tt0035423         4  nm0005227    actor  \N  ["Charlie McKay"]
# 4  tt0118589         1  nm0001014  actress  \N   ["Billie Frank"]

# %%
total_movies.genres_sep.value_counts()
# Out:
# Drama          82766
# Documentary    74965
# Comedy         41678
# Action         17348
# Thriller       17275
# Romance        17110
# Horror         15502
# Crime          11645
# Biography       9915
# Adventure       9056
# Family          8141
# History         7476
# Mystery         7173
# Music           6741
# Fantasy         5665
# Sci-Fi          4667
# Animation       4278
# Sport           3864
# Musical         2397
# War             2366
# News            1300
# Adult           1277
# Western          681
# Reality-TV       284
# Talk-Show         82
# Short             34
# Game-Show         10
# Name: genres_sep, dtype: int64

# %%
# movies.averageRating.value_counts()

# %%
# movies_exp.groupby("genres_sep")["tconst"].count()

# %%
# movies_exp.genres_sep.value_counts()

# %%
# principals.shape

# %%
# principals.tconst.nunique()

# %% [markdown]
# ### add ethinicity based on nconst, year based on tconst
#
# #### x year, y count

# %%
filtered_movies.shape
# Out:
# (3587, 19)

# %%
# pd.concat([df1, filtered_movies], axis=1, join="inner")

# %%
merged_year = pd.merge(principals, filtered_movies, on='tconst')
merged_year.shape
# Out:
# (14122, 24)

# %%
merged_year_ethnicity = pd.merge(merged_year, ethnicity, on='nconst')

# %%
merged_year_ethnicity.columns
# Out:
# Index(['tconst', 'ordering', 'nconst', 'category', 'job', 'characters',
#        'index', 'titleType', 'primaryTitle', 'originalTitle', 'isAdult',
#        'startYear', 'endYear', 'runtimeMinutes', 'genres', 'tmdb_id',
#        'og_language', 'budget', 'revenue', 'ratio', 'ROI', 'averageRating',
#        'numVotes', 'Unnamed: 18', 'Unnamed: 0', 'first_name', 'last_name',
#        'NEW_ACTOR_RACE', 'race'],
#       dtype='object')

# %%
merged_year_ethnicity_clean = merged_year_ethnicity[["startYear", "NEW_ACTOR_RACE", "tconst"]]

# %%
merged_year_ethnicity_clean.head()
# Out:
#    startYear NEW_ACTOR_RACE     tconst
# 0       2001              w  tt0035423
# 1       2000              w  tt0162983
# 2       2003              w  tt0199626
# 3       2004              w  tt0312329
# 4       2007              w  tt0419843

# %%
merged_year_ethnicity_clean["NEW_ACTOR_RACE"].nunique()
# Out:
# 9

# %%
merged_year_ethnicity_clean.groupby(["startYear","NEW_ACTOR_RACE"]).size()
# Out:
# startYear  NEW_ACTOR_RACE
# 2000       HL+M                5
#            HL+O                9
#            NL+M               11
#            NL+O               27
#            a                  18
#                             ...
# 2019       a                  43
#            b                  63
#            i                  15
#            l                   4
#            w                 266
# Length: 180, dtype: int64

# %%
grouped_df = merged_year_ethnicity_clean.groupby(["startYear","NEW_ACTOR_RACE"]).count()
grouped_df
# Out:
#                           tconst
# startYear NEW_ACTOR_RACE
# 2000      HL+M                 5
#           HL+O                 9
#           NL+M                11
#           NL+O                27
#           a                   18
# ...                          ...
# 2019      a                   43
#           b                   63
#           i                   15
#           l                    4
#           w                  266
#
# [180 rows x 1 columns]

# %%
grouped_df.tconst
# Out:
# startYear  NEW_ACTOR_RACE
# 2000       HL+M                5
#            HL+O                9
#            NL+M               11
#            NL+O               27
#            a                  18
#                             ...
# 2019       a                  43
#            b                  63
#            i                  15
#            l                   4
#            w                 266
# Name: tconst, Length: 180, dtype: int64

# %%
df = grouped_df["tconst"]
df.unstack()
# Out:
# NEW_ACTOR_RACE  HL+M  HL+O  NL+M  NL+O   a    b   i   l    w
# startYear
# 2000               5     9    11    27  18   75  14   9  381
# 2001               5    13    13    39  20   81  16   7  420
# 2002              11    13    21    37  22   89  16  12  415
# 2003               9    10    14    30  22   77  14  10  442
# 2004              10    19    11    33  39   85  19   8  459
# 2005               8    16    26    63  37   86  21   9  503
# 2006               8    19    28    65  48  114  28   5  521
# 2007              10    21    19    51  59   83  24  19  497
# 2008              12    14    25    35  52   83  21   9  509
# 2009              18    17    25    52  48  106  21   8  533
# 2010              15    19    21    37  44   81  21  10  501
# 2011              12    11    31    48  33   79  17   8  569
# 2012               6    25    31    53  42   68  18   8  442
# 2013               4    22    33    57  60   93  25  10  483
# 2014              13    21    37    50  45   95  25  10  503
# 2015              10    18    34    41  48   81  26   4  449
# 2016               9    24    28    42  51  113  23   6  462
# 2017               4    16    35    53  50   78  29   3  376
# 2018               4    22    25    53  47   89  31   7  324
# 2019              10    17    25    41  43   63  15   4  266

# %%
sns.set_palette("PuBuGn_d")
sns.set_context("talk")
 

# sns.set_palette('RdBu', n_colors=9)


# Create the Seaborn plot
ax = sns.lineplot(data=grouped_df, x="startYear", y="tconst", hue="NEW_ACTOR_RACE",legend='brief',style="NEW_ACTOR_RACE",linewidth=3 ) 


# Change the x-axis label
ax.set_xlabel('Year')

# Change the y-axis label
ax.set_ylabel('Total number of Principal Cast')

years = range(df.unstack().index.min(), df.unstack().index.max() + 1)
ax.set_xticks(years)


# Adjust the size of the figure
ax.figure.set_size_inches(12, 8)

plt.legend(loc='upper right', title='Ethnicity')

# %%
years = range(df.unstack().index.min(), df.unstack().index.max() + 1)
year_labels = ["'"+str(y)[2:] for y in years]

year_labels_dict = dict(zip(years,year_labels ))
year_labels_dict
# Out:
# {2000: "'00",
#  2001: "'01",
#  2002: "'02",
#  2003: "'03",
#  2004: "'04",
#  2005: "'05",
#  2006: "'06",
#  2007: "'07",
#  2008: "'08",
#  2009: "'09",
#  2010: "'10",
#  2011: "'11",
#  2012: "'12",
#  2013: "'13",
#  2014: "'14",
#  2015: "'15",
#  2016: "'16",
#  2017: "'17",
#  2018: "'18",
#  2019: "'19"}

# %%
# Create the Seaborn plot
plt.figure(dpi=300)

sns.reset_defaults()
# sns.set(rc={ 'axes.facecolor':'white' ,"grid.color": "grey", "grid.linestyle": ":"})
# sns.set_context("talk")
# marker_options = [".", ",", "o", "v", "^", "<", ">", "1", "2"]

ax = sns.lineplot(data=grouped_df, x="startYear", y="tconst", hue="NEW_ACTOR_RACE",legend='brief',style="NEW_ACTOR_RACE",linewidth=3 )
ax.legend(bbox_to_anchor=(1.25, 1),loc='upper right', title='Ethnicity', labels=["H/L, More", "H/L, Other", "Not H/L, More","Not H/L, Other","Asian","Black","Indigenous","Latinx","White"], prop={'size': 10})

# Change the x-axis label
ax.set_xlabel('Year' )

# Change the y-axis label
ax.set_ylabel('Total number of Principal Cast' )

years = range(df.unstack().index.min(), df.unstack().index.max() + 1)
ax.set_xticks(years)
ax.set_xticklabels(year_labels)

# ax.figure.set_facecolor("white")

# Adjust the size of the figure
ax.figure.set_size_inches(10, 6)
# plt.xticks(rotation=45)
plt.grid()
# plt.setp(ax.patches, linewidth=1)
plt.show()

# %%
unstacked_df = grouped_df.unstack()
unstacked_df.reset_index(level=[0]).to_csv("testing.csv")

# %%
unstacked_df.columns
# Out:
# MultiIndex([('tconst', 'HL+M'),
#             ('tconst', 'HL+O'),
#             ('tconst', 'NL+M'),
#             ('tconst', 'NL+O'),
#             ('tconst',    'a'),
#             ('tconst',    'b'),
#             ('tconst',    'i'),
#             ('tconst',    'l'),
#             ('tconst',    'w')],
#            names=[None, 'NEW_ACTOR_RACE'])

# %%
grouped_df
# Out:
#                           tconst
# startYear NEW_ACTOR_RACE
# 2000      HL+M                 5
#           HL+O                 9
#           NL+M                11
#           NL+O                27
#           a                   18
# ...                          ...
# 2019      a                   43
#           b                   63
#           i                   15
#           l                    4
#           w                  266
#
# [180 rows x 1 columns]

# %%
# calculate chi-squared statistic and p-value for genres
# chi2, p_value = stats.chisquare(cast_df.genres, dummy_df.genres)
# print(f'Chi-squared statistic for genres: {chi2}')
# print(f'p-value for genres: {p_value}')

# %%
# # calculate chi-squared statistic and p-value for ratings
# chi2, p_value = stats.chisquare(rating_pop1, rating_pop2)
# print(f'Chi-squared statistic for ratings: {chi2}')
# print(f'p-value for ratings: {p_value}')

# # calculate chi-squared statistic and p-value for budgets
# chi2, p_value = stats.chisquare(budget_pop1, budget_pop2)
# print(f'Chi-squared statistic for budgets: {chi2}')
# print(f'p-value for budgets: {p_value}')

# # calculate chi-squared statistic and p-value for revenues
# chi2, p_value = stats.chisquare(revenue_pop1, revenue_pop2)
# print(f'Chi-squared statistic for revenues: {chi2}')
# print(f'p-value for revenues: {p_value}')

# %%
test = pd.read_csv("testing.csv")
test
# Out:
#         Unnamed: 0  startYear tconst tconst.1 tconst.2 tconst.3 tconst.4  \
# 0   NEW_ACTOR_RACE        NaN   HL+M     HL+O     NL+M     NL+O        a
# 1                0     2000.0      5        9       11       27       18
# 2                1     2001.0      5       13       13       39       20
# 3                2     2002.0     11       13       21       37       22
# 4                3     2003.0      9       10       14       30       22
# 5                4     2004.0     10       19       11       33       39
# 6                5     2005.0      8       16       26       63       37
# 7                6     2006.0      8       19       28       65       48
# 8                7     2007.0     10       21       19       51       59
# 9                8     2008.0     12       14       25       35       52
# 10               9     2009.0     18       17       25       52       48
# 11              10     2010.0     15       19       21       37       44
# 12              11     2011.0     12       11       31       48       33
# 13              12     2012.0      6       25       31       53       42
# 14              13     2013.0      4       22       33       57       60
# 15              14     2014.0     13       21       37       50       45
# 16              15     2015.0     10       18       34       41       48
# 17              16     2016.0      9       24       28       42       51
# 18              17     2017.0      4       16       35       53       50
# 19              18     2018.0      4       22       25       53       47
# 20              19     2019.0     10       17       25       41       43
#
#    tconst.5 tconst.6 tconst.7 tconst.8
# 0         b        i        l        w
# 1        75       14        9      381
# 2        81       16        7      420
# 3        89       16       12      415
# 4        77       14       10      442
# 5        85       19        8      459
# 6        86       21        9      503
# 7       114       28        5      521
# 8        83       24       19      497
# 9        83       21        9      509
# 10      106       21        8      533
# 11       81       21       10      501
# 12       79       17        8      569
# 13       68       18        8      442
# 14       93       25       10      483
# 15       95       25       10      503
# 16       81       26        4      449
# 17      113       23        6      462
# 18       78       29        3      376
# 19       89       31        7      324
# 20       63       15        4      266

# %%
test = test.reset_index(drop=True)

# %%
test = test.drop("NEW_ACTOR_RACE", axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/lj/zpnly2t14hz991pch7j3hmm40000gn/T/ipykernel_49375/1369000846.py in <module>
# ----> 1 test = test.drop("NEW_ACTOR_RACE", axis=1)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['NEW_ACTOR_RACE'] not found in axis"

# %%
test["total"] = test.sum()

# %%
test["total"]
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# Name: total, dtype: object

# %%
testing_prop = pd.read_csv("testing_prop.csv")
testing_prop.head()
# Out:
#    NEW_ACTOR_RACE  startYear  HL+M  HL+O  NL+M  NL+O   a   b   i   l  ...  \
# 0               0       2000     5     9    11    27  18  75  14   9  ...
# 1               1       2001     5    13    13    39  20  81  16   7  ...
# 2               2       2002    11    13    21    37  22  89  16  12  ...
# 3               3       2003     9    10    14    30  22  77  14  10  ...
# 4               4       2004    10    19    11    33  39  85  19   8  ...
#
#    Total  Proportion NL+M  Proportion HL+O  Proportion NL+M.1  \
# 0    549         0.009107         0.016393           0.020036
# 1    614         0.008143         0.021173           0.021173
# 2    636         0.017296         0.020440           0.033019
# 3    628         0.014331         0.015924           0.022293
# 4    683         0.014641         0.027818           0.016105
#
#    Proportion  NL+O  Proportion  a  Proportion  b  Proportion i  Proportion l  \
# 0          0.049180       0.032787       0.136612      0.025501      0.016393
# 1          0.063518       0.032573       0.131922      0.026059      0.011401
# 2          0.058176       0.034591       0.139937      0.025157      0.018868
# 3          0.047771       0.035032       0.122611      0.022293      0.015924
# 4          0.048316       0.057101       0.124451      0.027818      0.011713
#
#    Proportion w
# 0      0.693989
# 1      0.684039
# 2      0.652516
# 3      0.703822
# 4      0.672035
#
# [5 rows x 21 columns]

# %%
# ax = sns.lineplot(data=grouped_df, x="startYear", y="Proportion w" ,legend='brief', linewidth=3 )

# %%
testing_prop["Proportion w"]
# Out:
# 0     0.693989
# 1     0.684039
# 2     0.652516
# 3     0.703822
# 4     0.672035
# 5     0.654096
# 6     0.623206
# 7     0.634738
# 8     0.669737
# 9     0.643720
# 10    0.668892
# 11    0.704208
# 12    0.637807
# 13    0.613723
# 14    0.629537
# 15    0.631505
# 16    0.609499
# 17    0.583851
# 18    0.538206
# 19    0.549587
# Name: Proportion w, dtype: float64

# %%
# for col in range(y.shape[1]):
#     plot(x, y[:, col])
for i in testing_prop.columns[12:]:
    print(i)
    plt.plot(testing_prop["startYear"], testing_prop[i])
# plt.plot(testing_prop["startYear"], testing_prop["Proportion NL+M"])
# plt.plot(testing_prop["startYear"], testing_prop["Proportion  L+M"])
# plt.plot(testing_prop["startYear"], testing_prop["Proportion  a"])

# plt.plot(testing_prop["startYear"], testing_prop["Proportion  a"])

# plt.plot(testing_prop["startYear"], testing_prop["Proportion  a"])

plt.show()
# Out:
# Proportion NL+M
# Proportion HL+O
# Proportion NL+M.1
# Proportion  NL+O
# Proportion  a
# Proportion  b
# Proportion i
# Proportion l
# Proportion w

# %%
testing_prop
# Out:
#     NEW_ACTOR_RACE  startYear  HL+M  HL+O  NL+M  NL+O   a    b   i   l  ...  \
# 0                0       2000     5     9    11    27  18   75  14   9  ...
# 1                1       2001     5    13    13    39  20   81  16   7  ...
# 2                2       2002    11    13    21    37  22   89  16  12  ...
# 3                3       2003     9    10    14    30  22   77  14  10  ...
# 4                4       2004    10    19    11    33  39   85  19   8  ...
# 5                5       2005     8    16    26    63  37   86  21   9  ...
# 6                6       2006     8    19    28    65  48  114  28   5  ...
# 7                7       2007    10    21    19    51  59   83  24  19  ...
# 8                8       2008    12    14    25    35  52   83  21   9  ...
# 9                9       2009    18    17    25    52  48  106  21   8  ...
# 10              10       2010    15    19    21    37  44   81  21  10  ...
# 11              11       2011    12    11    31    48  33   79  17   8  ...
# 12              12       2012     6    25    31    53  42   68  18   8  ...
# 13              13       2013     4    22    33    57  60   93  25  10  ...
# 14              14       2014    13    21    37    50  45   95  25  10  ...
# 15              15       2015    10    18    34    41  48   81  26   4  ...
# 16              16       2016     9    24    28    42  51  113  23   6  ...
# 17              17       2017     4    16    35    53  50   78  29   3  ...
# 18              18       2018     4    22    25    53  47   89  31   7  ...
# 19              19       2019    10    17    25    41  43   63  15   4  ...
#
#     Total  Proportion NL+M  Proportion HL+O  Proportion NL+M.1  \
# 0     549         0.009107         0.016393           0.020036
# 1     614         0.008143         0.021173           0.021173
# 2     636         0.017296         0.020440           0.033019
# 3     628         0.014331         0.015924           0.022293
# 4     683         0.014641         0.027818           0.016105
# 5     769         0.010403         0.020806           0.033810
# 6     836         0.009569         0.022727           0.033493
# 7     783         0.012771         0.026820           0.024266
# 8     760         0.015789         0.018421           0.032895
# 9     828         0.021739         0.020531           0.030193
# 10    749         0.020027         0.025367           0.028037
# 11    808         0.014851         0.013614           0.038366
# 12    693         0.008658         0.036075           0.044733
# 13    787         0.005083         0.027954           0.041931
# 14    799         0.016270         0.026283           0.046308
# 15    711         0.014065         0.025316           0.047820
# 16    758         0.011873         0.031662           0.036939
# 17    644         0.006211         0.024845           0.054348
# 18    602         0.006645         0.036545           0.041528
# 19    484         0.020661         0.035124           0.051653
#
#     Proportion  NL+O  Proportion  a  Proportion  b  Proportion i  \
# 0           0.049180       0.032787       0.136612      0.025501
# 1           0.063518       0.032573       0.131922      0.026059
# 2           0.058176       0.034591       0.139937      0.025157
# 3           0.047771       0.035032       0.122611      0.022293
# 4           0.048316       0.057101       0.124451      0.027818
# 5           0.081925       0.048114       0.111834      0.027308
# 6           0.077751       0.057416       0.136364      0.033493
# 7           0.065134       0.075351       0.106003      0.030651
# 8           0.046053       0.068421       0.109211      0.027632
# 9           0.062802       0.057971       0.128019      0.025362
# 10          0.049399       0.058745       0.108144      0.028037
# 11          0.059406       0.040842       0.097772      0.021040
# 12          0.076479       0.060606       0.098124      0.025974
# 13          0.072427       0.076239       0.118170      0.031766
# 14          0.062578       0.056320       0.118899      0.031289
# 15          0.057665       0.067511       0.113924      0.036568
# 16          0.055409       0.067282       0.149077      0.030343
# 17          0.082298       0.077640       0.121118      0.045031
# 18          0.088040       0.078073       0.147841      0.051495
# 19          0.084711       0.088843       0.130165      0.030992
#
#     Proportion l  Proportion w
# 0       0.016393      0.693989
# 1       0.011401      0.684039
# 2       0.018868      0.652516
# 3       0.015924      0.703822
# 4       0.011713      0.672035
# 5       0.011704      0.654096
# 6       0.005981      0.623206
# 7       0.024266      0.634738
# 8       0.011842      0.669737
# 9       0.009662      0.643720
# 10      0.013351      0.668892
# 11      0.009901      0.704208
# 12      0.011544      0.637807
# 13      0.012706      0.613723
# 14      0.012516      0.629537
# 15      0.005626      0.631505
# 16      0.007916      0.609499
# 17      0.004658      0.583851
# 18      0.011628      0.538206
# 19      0.008264      0.549587
#
# [20 rows x 21 columns]
